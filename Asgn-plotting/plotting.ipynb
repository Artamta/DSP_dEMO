# %%
import matplotlib.pyplot as plt
import numpy as np
x=[1,2]
y=[2,3]
fig = plt.bar(x,y)
plt.xlabel("a")
plt.ylabel("b")
# Out:
# Text(0, 0.5, 'b')

# %%
import pandas as pd

a = pd.read_csv("/Users/ayush/Desktop/dsp/DSP_dEMO/Asgn-plotting/iip_wrt_prevyr.csv") 
print(a.head)
# Out:
# <bound method NDFrame.head of        Year  Mining  Manufacturing  Electricity  General
# 0   2012-13    -5.3            4.8          4.0      3.3
# 1   2013-14    -0.1            3.6          6.1      3.3
# 2   2014-15    -1.4            3.8         14.8      4.0
# 3   2015-16     4.3            2.8          5.7      3.3
# 4   2016-17     5.3            4.4          5.8      4.6
# 5   2017-18     2.3            4.6          5.4      4.4
# 6   2018-19     2.9            3.9          5.2      3.8
# 7   2019-20     1.6           -1.4          1.0     -0.8
# 8   2020-21    -7.8           -9.6         -0.5     -8.4
# 9   2021-22    12.2           11.8          7.9     11.4
# 10  2022-23     5.8            4.7          8.9      5.2
# 11  2023-24     7.5            5.5          7.1      5.9
# 12  2024-25     3.0            4.1          5.2      4.0>

# %%
year = a.Year
mining = a.Mining
manf = a.Manufacturing
ele = a.Electricity
gen = a.General

fig, ax = plt.subplots()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.set_xticks([])
ax.set_yticks([])

ax.axhline(y=0, color='black', linewidth=0.5#,"-")   # X-axis

ax.bar(year,mining,label = "Mining",color='LightSkyBlue',linewidth=1)

ax.bar(year,manf,bottom=mining , label = "Manuf",color='IndianRed',linewidth=1)

ax.bar(year,ele,bottom=mining+manf,label = "Electricity",color='LightSalmon',linewidth=1)

ax.bar(year,gen,bottom=mining+manf+ele,label = "Genral",color='Moccasin',linewidth=1)

ax.legend(ncols=2)

ax.set_title("IP GROWTH FOR INDIA", fontsize=14)
ax.set_xlabel("Finential Year")
ax.set_ylabel("IP Gwowth Rate wrt Prev Year",fontsize=12,loc='bottom')
# Out:
#   Cell In[187], line 15
#     ax.axhline(y=0, color='black', linewidth=0.5,"-")   # X-axis
#                                                     ^
# SyntaxError: positional argument follows keyword argument
